# %%
from core.db.crud.news_crud import NewsArticleRepository, NewsArticleSummaryRepository
from core.db.db_utils import get_db
from core.db.news_tables import NewsArticleORM
from core.langchain_summarizer.summary_chain import ArticleSummary, get_summary
from core.scrapper.cnn_scrapper import CNNScraper
from icecream import ic
import nest_asyncio

nest_asyncio.apply()

cnn_scapper = CNNScraper(enable_cache=True)
articles = cnn_scapper.run(n=3)

news_repo = NewsArticleRepository()
summary_repo = NewsArticleSummaryRepository()
# Out:
# [2024-04-05 11:48:50,701: DEBUG: connectionpool: Starting new HTTPS connection (1): edition.cnn.com:443]
# [2024-04-05 11:48:51,164: DEBUG: connectionpool: https://edition.cnn.com:443 "GET / HTTP/1.1" 200 436336]
# Response code: 200
# [2024-04-05 11:48:52,088: DEBUG: base_scrapper: Found 14 articles and 138 other pages]
# [2024-04-05 11:48:52,091: DEBUG: cnn_scrapper: Found 14 Scrapable article links]
# [2024-04-05 11:48:55,156: DEBUG: base_scrapper: Found 3 full articles]
# [2024-04-05 11:48:55,159: DEBUG: base_scrapper: Filtered 0 empty articles]

# %%
# for num,article in enumerate(articles,1):
    
    
#     article_orm = news_repo.add(article, db=next(get_db()))
    
#     # article_summary = get_summary(article=article.content)
    
#     # if isinstance(article_summary, ArticleSummary):
#     #     summary_obj = summary_repo.map_to_orm(article_summary)
#     #     summary_obj.article_id = article_orm.id
#     #     summary_repo.add(summary_obj, db=next(get_db()))        
#     # # add_article(article=article, db=next(get_db()), orm_class=NewsArticleORM )
    
#     # print()
#     # print(f"{num}  :  {article.title}")
#     ic(article.title)
    
#     ic(article_orm.__repr__())
#     print()
#     # print("ai_title: ", article.meta_data.get("ai_title", None))
#     # print("content length", len(article.content.split()))
#     # print("summary length", len(article.content_summary.split()))
#     # print("Compressed to: ", (len(article.content_summary.split())/len(article.content.split())) * 100 , "%")
    
# # cnn_scapper.write_db(session=next(get_db()), orm_class=NewsArticleORM)
# print("Done!!!")

# %%
a = articles[0]
a.title
# Out:
# 'US awaits Netanyahu’s response after Biden’s ultimatum'

# %%
a_orm = news_repo.add(a, db=next(get_db()))
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~/.cache/pypoetry/virtualenvs/news-app-rmFgPn8S-py3.12/lib/python3.12/site-packages/sqlalchemy/engine/base.py:1971, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1970     if not evt_handled:
# -> 1971         self.dialect.do_execute(
#    1972             cursor, str_statement, effective_parameters, context
#    1973         )
#    1975 if self._has_events or self.engine._has_events:
#
# File ~/.cache/pypoetry/virtualenvs/news-app-rmFgPn8S-py3.12/lib/python3.12/site-packages/sqlalchemy/engine/default.py:919, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     918 def do_execute(self, cursor, statement, parameters, context=None):
# --> 919     cursor.execute(statement, parameters)
#
# OperationalError: attempt to write a readonly database
#
# ...

# %%
a_orm
# Out:
# ---------------------------------------------------------------------------
# DetachedInstanceError                     Traceback (most recent call last)
# File ~/.cache/pypoetry/virtualenvs/news-app-rmFgPn8S-py3.12/lib/python3.12/site-packages/IPython/core/formatters.py:711, in PlainTextFormatter.__call__(self, obj)
#     704 stream = StringIO()
#     705 printer = pretty.RepresentationPrinter(stream, self.verbose,
#     706     self.max_width, self.newline,
#     707     max_seq_length=self.max_seq_length,
#     708     singleton_pprinters=self.singleton_printers,
#     709     type_pprinters=self.type_printers,
#     710     deferred_pprinters=self.deferred_printers)
# --> 711 printer.pretty(obj)
#     712 printer.flush()
#     713 return stream.getvalue()
#
# File ~/.cache/pypoetry/virtualenvs/news-app-rmFgPn8S-py3.12/lib/python3.12/site-packages/IPython/lib/pretty.py:411, in RepresentationPrinter.pretty(self, obj)
#     408                         return meth(obj, self, cycle)
# ...
